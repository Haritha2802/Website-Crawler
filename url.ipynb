# %%
# !pip install google-auth google-auth-oauthlib google-api-python-client requests beautifulsoup4
# Out:
# Requirement already satisfied: google-auth in /usr/local/lib/python3.11/dist-packages (2.38.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (2.170.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (0.2.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.4.26)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.oauth2 import service_account
from googleapiclient.discovery import build
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import time
from io import BytesIO
from googleapiclient.http import MediaIoBaseDownload, MediaIoBaseUpload

# Update this path to where your service account JSON key is located
SERVICE_ACCOUNT_FILE = '/content/website-crawler-gcf-a0fa227f070b.json'

# Your Google Drive file ID for the text file that contains the start URL
FILE_ID = '1YUFAMR-28EddEz9IAdvdY-T9JPdgYOQ2'

SCOPES = ['https://www.googleapis.com/auth/drive']

visited_urls = set()

def is_valid_url(url):
    try:
        result = urlparse(url)
        return all([result.scheme, result.netloc])
    except ValueError:
        return False

def get_domain(url):
    return urlparse(url).netloc

def scan_website_recursively(start_url, base_domain, max_depth, current_depth=0):
    internal_links = []
    if current_depth > max_depth:
        return internal_links

    normalized_url = urljoin(start_url, urlparse(start_url).path)
    if normalized_url in visited_urls:
        return internal_links

    visited_urls.add(normalized_url)
    print(f"Crawling: {normalized_url} (Depth: {current_depth})")

    try:
        response = requests.get(normalized_url, timeout=10)
        response.raise_for_status()
    except requests.exceptions.RequestException as e:
        print(f"Failed to fetch {normalized_url}: {e}")
        return internal_links

    soup = BeautifulSoup(response.text, 'html.parser')

    for tag in soup.find_all('a', href=True):
        href = tag['href']
        full_url = urljoin(normalized_url, href)
        clean_url = urljoin(full_url, urlparse(full_url).path)

        if not is_valid_url(clean_url):
            continue

        if get_domain(clean_url) == base_domain and clean_url not in visited_urls:
            internal_links.append(clean_url)
            internal_links += scan_website_recursively(clean_url, base_domain, max_depth, current_depth + 1)

    time.sleep(0.5)  # polite delay to avoid hammering the server
    return internal_links

def get_url_from_drive():
    creds = service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)
    service = build('drive', 'v3', credentials=creds)

    request = service.files().get_media(fileId=FILE_ID)
    fh = BytesIO()
    downloader = MediaIoBaseDownload(fh, request)
    done = False
    while not done:
        status, done = downloader.next_chunk()

    url_text = fh.getvalue().decode("utf-8").strip()
    print(f"Start URL read from Drive file: {url_text}")
    return url_text

def upload_to_drive(content):
    creds = service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)
    service = build('drive', 'v3', credentials=creds)

    file_metadata = {'name': 'crawled_links.txt', 'mimeType': 'text/plain'}
    fh = BytesIO(content.encode('utf-8'))
    media = MediaIoBaseUpload(fh, mimetype='text/plain')
    uploaded_file = service.files().create(body=file_metadata, media_body=media, fields='id').execute()
    print(f"Uploaded crawled links file to Drive with File ID: {uploaded_file['id']}")
    return uploaded_file['id']

def main():
    start_url = get_url_from_drive()
    if not is_valid_url(start_url):
        print("Invalid URL in Drive file.")
        return

    base_domain = get_domain(start_url)
    print(f"Crawling domain: {base_domain}")

    results = scan_website_recursively(start_url, base_domain, max_depth=2)
    print(f"Found {len(results)} internal links.")

    content = "\n".join(results)
    upload_to_drive(content)

if __name__ == "__main__":
    main()
# Out:
# Start URL read from Drive file: https://www.w3schools.com
# Crawling domain: www.w3schools.com
# Crawling: https://www.w3schools.com (Depth: 0)
# Crawling: https://www.w3schools.com/academy/index.php (Depth: 1)
# Crawling: https://www.w3schools.com/spaces/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/plus/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/html/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/tags/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/css/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/cssref/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/css/css_rwd_intro.asp (Depth: 2)
# Crawling: https://www.w3schools.com/bootstrap/bootstrap_ver.asp (Depth: 2)
# Crawling: https://www.w3schools.com/w3css/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/w3css/w3css_references.asp (Depth: 2)
# Crawling: https://www.w3schools.com/sass/default.php (Depth: 2)
# Crawling: https://www.w3schools.com/sass/sass_functions_string.php (Depth: 2)
# Crawling: https://www.w3schools.com/colors/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/colors/colors_fs595.asp (Depth: 2)
# Crawling: https://www.w3schools.com/icons/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/icons/icons_reference.asp (Depth: 2)
# Crawling: https://www.w3schools.com/graphics/svg_intro.asp (Depth: 2)
# Crawling: https://www.w3schools.com/graphics/svg_reference.asp (Depth: 2)
# Crawling: https://www.w3schools.com/graphics/canvas_intro.asp (Depth: 2)
# Crawling: https://www.w3schools.com/graphics/canvas_reference.asp (Depth: 2)
# Crawling: https://www.w3schools.com/graphics/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/charsets/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/howto/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/ai/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/gen_ai/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/gen_ai/chatgpt-3-5/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/gen_ai/chatgpt-4/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/gen_ai/bard/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/python/python_ml_getting_started.asp (Depth: 2)
# Crawling: https://www.w3schools.com/dsa/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/datascience/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/python/numpy/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/python/pandas/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/python/scipy/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/python/matplotlib_intro.asp (Depth: 2)
# Crawling: https://www.w3schools.com/statistics/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/excel/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/googlesheets/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/where_to_start.asp (Depth: 2)
# Crawling: https://www.w3schools.com/w3css/w3css_templates.asp (Depth: 2)
# Crawling: https://www.w3schools.com/browsers/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/whatis/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/programming/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/tryit/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/typingspeed/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/codegame/index.html (Depth: 2)
# Crawling: https://www.w3schools.com/cybersecurity/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/accessibility/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/js/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/jsref/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/react/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/jquery/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/jquery/jquery_ref_overview.asp (Depth: 2)
# Crawling: https://www.w3schools.com/vue/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/vue/vue_ref_builtin-attributes.php (Depth: 2)
# Crawling: https://www.w3schools.com/angular/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/angular/angular_ref_directives.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_json_intro.asp (Depth: 2)
# Crawling: https://www.w3schools.com/jsref/jsref_obj_json.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_ajax_intro.asp (Depth: 2)
# Crawling: https://www.w3schools.com/appml/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/appml/appml_reference.asp (Depth: 2)
# Crawling: https://www.w3schools.com/w3js/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/w3js/w3js_references.asp (Depth: 2)
# Crawling: https://www.w3schools.com/python/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/python/python_reference.asp (Depth: 2)
# Crawling: https://www.w3schools.com/sql/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/sql/sql_ref_keywords.asp (Depth: 2)
# Crawling: https://www.w3schools.com/mysql/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/mysql/mysql_datatypes.asp (Depth: 2)
# Crawling: https://www.w3schools.com/php/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/php/php_ref_overview.asp (Depth: 2)
# Crawling: https://www.w3schools.com/java/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/java/java_ref_reference.asp (Depth: 2)
# Crawling: https://www.w3schools.com/c/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/c/c_ref_reference.php (Depth: 2)
# Crawling: https://www.w3schools.com/cpp/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/cpp/cpp_ref_reference.asp (Depth: 2)
# Crawling: https://www.w3schools.com/cs/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/r/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/kotlin/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/rust/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/go/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/django/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/django/django_ref_template_tags.php (Depth: 2)
# Crawling: https://www.w3schools.com/postgresql/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/typescript/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/asp/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/asp/asp_ref_vbscript_functions.asp (Depth: 2)
# Crawling: https://www.w3schools.com/nodejs/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/nodejs/ref_modules.asp (Depth: 2)
# Crawling: https://www.w3schools.com/nodejs/nodejs_raspberrypi.asp (Depth: 2)
# Crawling: https://www.w3schools.com/git/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/bash/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/mongodb/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/xml/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/xml/dom_nodetype.asp (Depth: 2)
# Crawling: https://www.w3schools.com/html/html_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/html/html_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/css/css_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/css/css_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/bootstrap/bootstrap_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/bootstrap/bootstrap_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/bootstrap4/bootstrap_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/bootstrap4/bootstrap_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/bootstrap5/bootstrap_exercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/bootstrap5/bootstrap_quiz.php (Depth: 2)
# Crawling: https://www.w3schools.com/dsa/dsa_exercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/dsa/dsa_quiz.php (Depth: 2)
# Crawling: https://www.w3schools.com/python/numpy/numpy_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/python/numpy/numpy_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/python/pandas/pandas_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/python/pandas/pandas_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/python/scipy/scipy_exercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/python/scipy/scipy_quiz.php (Depth: 2)
# Crawling: https://www.w3schools.com/excel/excel_exercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/exercises/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/quiztest/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/react/react_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/react/react_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/jquery/jquery_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/jquery/jquery_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/vue/vue_exercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/vue/vue_quiz.php (Depth: 2)
# Crawling: https://www.w3schools.com/python/python_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/python/python_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/sql/sql_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/sql/sql_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/mysql/mysql_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/mysql/mysql_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/php/php_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/php/php_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/java/java_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/java/java_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/c/c_exercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/c/c_quiz.php (Depth: 2)
# Crawling: https://www.w3schools.com/cpp/cpp_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/cpp/cpp_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/cs/cs_exercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/cs/cs_quiz.php (Depth: 2)
# Crawling: https://www.w3schools.com/r/r_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/r/r_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/kotlin/kotlin_exercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/kotlin/kotlin_quiz.php (Depth: 2)
# Crawling: https://www.w3schools.com/django/django_exercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/django/django_quiz.php (Depth: 2)
# Crawling: https://www.w3schools.com/postgresql/postgresql_exercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/postgresql/postgresql_quiz.php (Depth: 2)
# Crawling: https://www.w3schools.com/typescript/typescript_exercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/typescript/typescript_quiz.php (Depth: 2)
# Crawling: https://www.w3schools.com/git/git_exercises.asp (Depth: 2)
# Crawling: https://www.w3schools.com/git/git_quiz.asp (Depth: 2)
# Crawling: https://www.w3schools.com/bash/bash_exercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/bash/bash_quiz.php (Depth: 2)
# Crawling: https://www.w3schools.com/go/go_exercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/mongodb/mongodb_exercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/tutorials/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/references/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/videos/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/colors/colors_picker.asp (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_study_plans.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_certification_exams.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_online_ide.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_code_challenges_and_projects.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_students_progress.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_teaching_materials.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/syllabus.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_get_started.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_code_challenges_for_teaching.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_code_excercises.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_programming_assignments.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_ide_for_education.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_setup_overview.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_create_class.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_assign_learning_content.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_assign_activities.php (Depth: 2)
# Crawling: https://www.w3schools.com/academy/academy_student_invitations.php (Depth: 2)
# Crawling: https://www.w3schools.com/about/about_copyright.asp (Depth: 2)
# Crawling: https://www.w3schools.com/about/about_privacy.asp (Depth: 2)
# Crawling: https://www.w3schools.com/cssref/index.php (Depth: 2)
# Crawling: https://www.w3schools.com/bootstrap/bootstrap_ref_all_classes.asp (Depth: 2)
# Crawling: https://www.w3schools.com/colors/colors_names.asp (Depth: 2)
# Crawling: https://www.w3schools.com/java/java_ref_keywords.asp (Depth: 2)
# Crawling: https://www.w3schools.com/html/html_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/css/css_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/sql/sql_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/python/python_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/w3css/w3css_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/bootstrap/bootstrap_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/php/php_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/java/java_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/xml/xml_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/jquery/jquery_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/forum/default.asp (Depth: 2)
# Failed to fetch https://www.w3schools.com/forum/default.asp: 403 Client Error: Forbidden for url: https://w3schools.invisionzone.com/
# Crawling: https://www.w3schools.com/about/default.asp (Depth: 2)
# Crawling: https://www.w3schools.com/html/tryit.asp (Depth: 1)
# Crawling: https://www.w3schools.com/css/tryit.asp (Depth: 1)
# Crawling: https://www.w3schools.com/js/tryit.asp (Depth: 1)
# Crawling: https://www.w3schools.com/python/trypython.asp (Depth: 1)
# Crawling: https://www.w3schools.com/sql/trysql.asp (Depth: 1)
# Crawling: https://www.w3schools.com/js/js_json.asp (Depth: 1)
# Crawling: https://www.w3schools.com/js/js_intro.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_whereto.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_output.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_statements.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_syntax.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_comments.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_variables.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_let.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_const.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_operators.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_arithmetic.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_assignment.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_datatypes.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_functions.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_objects.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_object_property.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_object_method.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_object_display.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_object_constructors.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_events.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_strings.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_string_methods.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_string_search.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_string_templates.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_numbers.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_bigint.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_number_methods.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_number_properties.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_arrays.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_array_methods.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_array_search.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_array_sort.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_array_iteration.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_array_const.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_dates.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_date_formats.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_date_methods.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_date_methods_set.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_math.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_random.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_booleans.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_comparisons.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_if_else.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_switch.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_loop_for.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_loop_forin.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_loop_forof.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_loop_while.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_break.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_iterables.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_sets.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_set_methods.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_maps.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_map_methods.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_typeof.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_tostring.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_type_conversion.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_destructuring.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_bitwise.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_regexp.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_precedence.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_errors.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_scope.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_hoisting.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_strict.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_this.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_arrow_function.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_classes.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_modules.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_debugging.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_conventions.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_best_practices.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_mistakes.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_performance.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_reserved.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_versions.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_es5.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_es6.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_2016.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_2017.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_2018.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_2019.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_2020.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_2021.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_2022.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_2023.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_2024.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_ie_edge.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_history.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_object_definition.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_object_prototypes.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_object_methods.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_object_properties.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_object_accessors.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_object_protection.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_function_definition.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_function_parameters.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_function_invocation.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_function_call.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_function_apply.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_function_bind.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_function_closures.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_class_intro.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_class_inheritance.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_class_static.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_callback.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_asynchronous.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_promise.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_async.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_htmldom.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_htmldom_methods.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_htmldom_document.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_htmldom_elements.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_htmldom_html.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_validation.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_htmldom_css.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_htmldom_animate.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_htmldom_events.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_htmldom_eventlistener.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_htmldom_navigation.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_htmldom_nodes.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_htmldom_collections.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_htmldom_nodelist.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_window.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_window_screen.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_window_location.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_window_history.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_window_navigator.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_popup.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_timing.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_cookies.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_api_intro.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_validation_api.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_api_history.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_api_web_storage.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_api_web_workers.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_api_fetch.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_api_geolocation.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_ajax_http.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_ajax_http_send.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_ajax_http_response.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_ajax_xmlfile.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_ajax_php.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_ajax_asp.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_ajax_database.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_ajax_applications.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_ajax_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_json_syntax.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_json_xml.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_json_datatypes.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_json_parse.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_json_stringify.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_json_objects.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_json_arrays.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_json_server.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_json_php.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_json_html.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_json_jsonp.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_jquery_selectors.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_jquery_elements.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_jquery_css.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_jquery_dom.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_graphics.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_graphics_canvas.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_graphics_plotly.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_graphics_chartjs.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_graphics_google_chart.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_graphics_d3js.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_dom_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_input_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_ex_dom.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_events_examples.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_ex_browser.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_editor.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_website.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_syllabus.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_study_plan.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_interview_prep.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_bootcamp.asp (Depth: 2)
# Crawling: https://www.w3schools.com/js/js_exam.asp (Depth: 2)
# Crawling: https://www.w3schools.com/tryit/tryit.asp (Depth: 1)
# Crawling: https://www.w3schools.com/tryit/trycompiler.asp (Depth: 1)
# Found 83201 internal links.
# Uploaded crawled links file to Drive with File ID: 1mkwgzvLhmR9bph-fVkeVFWdDKWdciHYK

# %%
from google.oauth2 import service_account
from googleapiclient.discovery import build
from googleapiclient.http import MediaIoBaseDownload, MediaInMemoryUpload
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import time
from io import BytesIO

SERVICE_ACCOUNT_FILE = '/content/website-crawler-gcf-a0fa227f070b.json'  # your path
FILE_ID = '1YUFAMR-28EddEz9IAdvdY-T9JPdgYOQ2'  # your url.txt file
SCOPES = ['https://www.googleapis.com/auth/drive']

visited_urls = set()

# %%
def is_valid_url(url):
    try:
        result = urlparse(url)
        return all([result.scheme, result.netloc])
    except ValueError:
        return False

def get_domain(url):
    return urlparse(url).netloc

def scan_website_recursively(start_url, base_domain, max_depth, current_depth=0):
    internal_links = []
    if current_depth > max_depth:
        return internal_links

    normalized_url = urljoin(start_url, urlparse(start_url).path)
    if normalized_url in visited_urls:
        return internal_links

    visited_urls.add(normalized_url)

    try:
        response = requests.get(normalized_url, timeout=10)
        response.raise_for_status()
    except requests.exceptions.RequestException:
        return internal_links

    soup = BeautifulSoup(response.text, 'html.parser')

    for tag in soup.find_all('a', href=True):
        href = tag['href']
        full_url = urljoin(normalized_url, href)
        clean_url = urljoin(full_url, urlparse(full_url).path)

        if not is_valid_url(clean_url):
            continue

        if get_domain(clean_url) == base_domain and clean_url not in visited_urls:
            internal_links.append(clean_url)
            internal_links += scan_website_recursively(clean_url, base_domain, max_depth, current_depth + 1)

    time.sleep(0.5)
    return internal_links

# %%
def get_url_from_drive():
    creds = service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)
    service = build('drive', 'v3', credentials=creds)

    request = service.files().get_media(fileId=FILE_ID)
    fh = BytesIO()
    downloader = MediaIoBaseDownload(fh, request)
    done = False
    while not done:
        status, done = downloader.next_chunk()
    return fh.getvalue().decode("utf-8").strip()

# %%
def share_file_with_user(service, file_id, user_email):
    permission = {
        'type': 'user',
        'role': 'reader',
        'emailAddress': user_email,
    }
    service.permissions().create(fileId=file_id, body=permission).execute()

# %%
def upload_to_drive(content):
    creds = service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)
    service = build('drive', 'v3', credentials=creds)

    file_metadata = {'name': 'crawled_links.txt', 'mimeType': 'text/plain'}
    media = MediaInMemoryUpload(content.encode('utf-8'), mimetype='text/plain')
    uploaded_file = service.files().create(body=file_metadata, media_body=media, fields='id').execute()

    file_id = uploaded_file['id']
    share_file_with_user(service, file_id, 'erigalareddy123@gmail.com')
    print(f"Uploaded and shared file with File ID: {file_id}")
    return file_id

# %%
start_url = get_url_from_drive()
base_domain = get_domain(start_url)
results = scan_website_recursively(start_url, base_domain, max_depth=2)
content = "\n".join(results)
upload_to_drive(content)
# Out:
# Uploaded and shared file with File ID: 1c24zMzHi-S5HNr2-jZls4UP60Rhs3tRa
# '1c24zMzHi-S5HNr2-jZls4UP60Rhs3tRa'
